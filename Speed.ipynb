# %%
# !pip install ultralytics
# !pip install supervision==0.1.0
# !pip install matplotlib
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.198-py3-none-any.whl (641 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.7/641.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (17.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.198
# Collecting supervision==0.1.0
#   Downloading supervision-0.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from supervision==0.1.0) (1.23.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.1.0) (4.8.0.76)
# Installing collected packages: supervision
# Successfully installed supervision-0.1.0
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from ultralytics import YOLO
import supervision as sv
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tqdm.notebook import tqdm

# %%
import os
HOME = os.getcwd()
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %%
SOURCE_VIDEO_PATH="/content/drive/MyDrive/Speed Estimation/DJI_0850.mp4"
OUTPUT_VIDEO_PATH="/content/drive/MyDrive/Speed Estimation/output.mp4"
MODEL_PATH="/content/drive/MyDrive/Speed Estimation/best.pt"
video_info= VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
model= YOLO(MODEL_PATH)
CLASS_NAMES_DICT= model.names

# %%
from typing import List
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %%
import math

def rescale_factor(angle=78, height=180, width=1080):
  return ((math.tan(angle/2)*height)*2)/width
rescale_factor()
video_info.width
# Out:
# 3840

# %%
def get_center(box):
    x1, y1, x2, y2 = box
    center_x = (x1 + x2) / 2
    center_y = (y1 + y2) / 2
    return center_x, center_y

def calculate_speed(current_box, previous_box, time_interval=0.1):
    current_center = get_center(current_box)
    previous_center = get_center(previous_box)
    rescale_x= rescale_factor(width=video_info.width)
    rescale_y= rescale_factor(width=video_info.height)
    displacement = math.sqrt(((current_center[0] - previous_center[0])*rescale_x)**2 + ((current_center[1] - previous_center[1])*rescale_y)**2)
    speed = displacement / time_interval
    return speed

# %% [markdown]
# # **Code for Speed Estimation**

# %%
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=1, text_thickness=1, text_scale=.5)
current_position = {}
previous_position={}
labels=[]
data_list= []
frame_number=0
# open target video file
with VideoSink(OUTPUT_VIDEO_PATH,video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        labels=[]
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        current_position={x:y for x,y in zip(detections.tracker_id, detections.xyxy)}

        for _, _, class_id, tracker_id in detections:
          if ((tracker_id in previous_position.keys()) and (tracker_id in current_position.keys())):
            speed=calculate_speed(current_position[tracker_id], previous_position[tracker_id])
          else:
            speed=0
          data={}
          data['frame_number'] = frame_number
          data['tracker_id'] = tracker_id
          data['class']= class_id
          data['speed'] = speed
          # print(data)
          data_list.append(data)
          # print(data_list)
          labels.append(f"#{tracker_id} {speed:0.2f}km/hr")

        # print(previous_position, current_position)
        # updating line counter
        # line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        # line_annotator.annotate(frame=frame, line_counter=line_counter)
        previous_position=current_position
        # print(labels)
        sink.write_frame(frame)
        frame_number+= 1
        # %matplotlib inline
        # show_frame_in_notebook(frame, (16, 16))
        # break

df=pd.DataFrame(data_list)
# Out:
#   0%|          | 0/9022 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# 0: 640x1088 60 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 61 Carss, 2 LCVs, 10 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.8ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 1 LCV, 5 M2Ws, 3 MAVs, 4 Rickshaws, 1 Truck, 60.3ms
# Speed: 8.0ms preprocess, 60.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 1 LCV, 8 M2Ws, 3 MAVs, 3 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.5ms preprocess, 58.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 57 Carss, 1 LCV, 6 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 1 LCV, 3 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 6.3ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 66 Carss, 1 LCV, 4 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.5ms preprocess, 58.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 1 LCV, 5 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 1 LCV, 6 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 60.5ms
# Speed: 7.3ms preprocess, 60.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 63 Carss, 1 LCV, 8 M2Ws, 1 MAV, 3 Rickshaws, 1 Truck, 59.3ms
# Speed: 9.4ms preprocess, 59.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 8 M2Ws, 4 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 60 Carss, 1 LCV, 8 M2Ws, 3 Rickshaws, 2 Trucks, 58.8ms
# Speed: 7.5ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 63 Carss, 9 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 8 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.4ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 63 Carss, 7 M2Ws, 1 MAV, 4 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.4ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 54 Carss, 8 M2Ws, 1 MAV, 3 Rickshaws, 2 Trucks, 62.1ms
# Speed: 7.7ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 55 Carss, 4 M2Ws, 2 Rickshaws, 1 Truck, 60.2ms
# Speed: 7.5ms preprocess, 60.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 10 M2Ws, 3 Rickshaws, 1 Truck, 58.5ms
# Speed: 9.2ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 60 Carss, 9 M2Ws, 4 Rickshaws, 1 Truck, 58.9ms
# Speed: 8.2ms preprocess, 58.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 10 M2Ws, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 9 M2Ws, 1 MAV, 3 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.9ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 11 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.3ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 1 LCV, 9 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 59.6ms
# Speed: 8.7ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 60 Carss, 1 LCV, 10 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 58.7ms
# Speed: 14.3ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 1 LCV, 11 M2Ws, 10 Rickshaws, 2 Trucks, 59.0ms
# Speed: 8.7ms preprocess, 59.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 1 LCV, 13 M2Ws, 8 Rickshaws, 2 Trucks, 58.5ms
# Speed: 7.5ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 1 LCV, 12 M2Ws, 8 Rickshaws, 2 Trucks, 62.0ms
# Speed: 7.4ms preprocess, 62.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 1 LCV, 12 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.5ms
# Speed: 8.0ms preprocess, 58.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 9 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.5ms
# Speed: 7.9ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 56 Carss, 1 LCV, 9 M2Ws, 1 MAV, 8 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.1ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.6ms
# Speed: 8.0ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 12 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.6ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 11 M2Ws, 1 MAV, 8 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 10 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.4ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 11 M2Ws, 8 Rickshaws, 2 Trucks, 60.8ms
# Speed: 7.5ms preprocess, 60.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 61 Carss, 1 LCV, 13 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 66 Carss, 1 LCV, 12 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 59.5ms
# Speed: 9.7ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 67 Carss, 1 LCV, 12 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.9ms
# Speed: 11.0ms preprocess, 58.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 1 LCV, 15 M2Ws, 1 MAV, 4 Rickshaws, 2 Trucks, 59.1ms
# Speed: 7.5ms preprocess, 59.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 15 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 59.7ms
# Speed: 12.2ms preprocess, 59.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 14 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 16.1ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 60 Carss, 1 LCV, 9 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 63.8ms
# Speed: 15.7ms preprocess, 63.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 57 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 61.0ms
# Speed: 16.3ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 56 Carss, 1 LCV, 6 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.6ms
# Speed: 9.0ms preprocess, 58.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 63.0ms
# Speed: 8.5ms preprocess, 63.0ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 15.2ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 1 LCV, 10 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 9.1ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 11 M2Ws, 1 MAV, 3 Rickshaws, 1 Truck, 64.1ms
# Speed: 14.8ms preprocess, 64.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 9 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 62.7ms
# Speed: 7.5ms preprocess, 62.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 62.8ms
# Speed: 15.6ms preprocess, 62.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 2 LCVs, 6 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 64.8ms
# Speed: 9.4ms preprocess, 64.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 70 Carss, 1 LCV, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 64.7ms
# Speed: 14.7ms preprocess, 64.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 11 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 60.4ms
# Speed: 10.6ms preprocess, 60.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 11 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 59.2ms
# Speed: 8.9ms preprocess, 59.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 65 Carss, 9 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 17.5ms preprocess, 58.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 66 Carss, 7 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.2ms
# Speed: 14.2ms preprocess, 59.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 61 Carss, 6 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.6ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 6 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.1ms
# Speed: 17.7ms preprocess, 59.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 8 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 13.2ms preprocess, 58.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 10 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 13.8ms preprocess, 58.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 13 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.9ms
# Speed: 12.4ms preprocess, 58.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 10 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 15.1ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 8.7ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 61 Carss, 9 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 5 M2Ws, 1 MAV, 3 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.6ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 61 Carss, 7 M2Ws, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.5ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 57 Carss, 5 M2Ws, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.3ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 59 Carss, 2 LCVs, 3 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 60 Carss, 2 LCVs, 8 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 59.9ms
# Speed: 7.5ms preprocess, 59.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 1 LCV, 9 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.5ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 67 Carss, 1 LCV, 10 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 67 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.4ms
# Speed: 7.8ms preprocess, 59.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 66 Carss, 1 LCV, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.9ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 67 Carss, 1 LCV, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 1 LCV, 7 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.3ms
# Speed: 7.6ms preprocess, 58.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 66 Carss, 1 LCV, 8 M2Ws, 3 MAVs, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 58 Carss, 1 LCV, 8 M2Ws, 3 MAVs, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 63 Carss, 1 LCV, 8 M2Ws, 3 MAVs, 5 Rickshaws, 1 Truck, 59.1ms
# Speed: 7.5ms preprocess, 59.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 64 Carss, 2 LCVs, 11 M2Ws, 3 MAVs, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 9.2ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 65 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 65 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 8.3ms preprocess, 58.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 59.1ms
# Speed: 8.0ms preprocess, 59.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 67 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.1ms
# Speed: 8.2ms preprocess, 59.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 12 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.6ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 67 Carss, 1 LCV, 12 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.9ms preprocess, 58.8ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 63 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 60.8ms
# Speed: 10.0ms preprocess, 60.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 2 LCVs, 12 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.9ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 2 LCVs, 7 M2Ws, 3 MAVs, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.1ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.6ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 5 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 63.4ms
# Speed: 7.9ms preprocess, 63.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 2 LCVs, 7 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 62.4ms
# Speed: 7.7ms preprocess, 62.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.6ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 59 Carss, 1 LCV, 6 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 59.8ms
# Speed: 8.5ms preprocess, 59.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 8 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 62 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 59.6ms
# Speed: 7.7ms preprocess, 59.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 60 Carss, 2 LCVs, 6 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.9ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 62 Carss, 2 LCVs, 5 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 61.2ms
# Speed: 13.4ms preprocess, 61.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 64.8ms
# Speed: 9.0ms preprocess, 64.8ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 2 LCVs, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 59.0ms
# Speed: 13.3ms preprocess, 59.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 59.7ms
# Speed: 14.6ms preprocess, 59.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 9 Rickshaws, 2 Trucks, 61.6ms
# Speed: 23.5ms preprocess, 61.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 79.0ms
# Speed: 16.5ms preprocess, 79.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 5 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 59.7ms
# Speed: 12.7ms preprocess, 59.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.5ms
# Speed: 11.7ms preprocess, 58.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 4 M2Ws, 2 MAVs, 8 Rickshaws, 2 Trucks, 58.9ms
# Speed: 9.5ms preprocess, 58.9ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 6 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 65.0ms
# Speed: 8.2ms preprocess, 65.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 60.8ms
# Speed: 10.8ms preprocess, 60.8ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.7ms
# Speed: 9.8ms preprocess, 58.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 9 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 63.3ms
# Speed: 22.2ms preprocess, 63.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 9 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.4ms
# Speed: 43.7ms preprocess, 58.4ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 9 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 68.7ms
# Speed: 29.7ms preprocess, 68.7ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 53 Carss, 1 LCV, 12 M2Ws, 5 Rickshaws, 2 Trucks, 60.4ms
# Speed: 8.9ms preprocess, 60.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 53 Carss, 1 LCV, 11 M2Ws, 5 Rickshaws, 2 Trucks, 59.0ms
# Speed: 12.9ms preprocess, 59.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 54 Carss, 1 LCV, 11 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.2ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 10 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 59.4ms
# Speed: 8.0ms preprocess, 59.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.2ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 16 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.9ms
# Speed: 8.0ms preprocess, 58.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 14 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.9ms preprocess, 58.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 52 Carss, 1 LCV, 10 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.5ms
# Speed: 8.3ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 54 Carss, 1 LCV, 11 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 61.6ms
# Speed: 10.7ms preprocess, 61.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 50 Carss, 2 LCVs, 12 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 60.2ms
# Speed: 11.0ms preprocess, 60.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 52 Carss, 2 LCVs, 13 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 59.5ms
# Speed: 9.3ms preprocess, 59.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 56 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 55 Carss, 1 LCV, 13 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.9ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 54 Carss, 1 LCV, 11 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.3ms
# Speed: 7.3ms preprocess, 60.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 14 M2Ws, 5 Rickshaws, 1 Truck, 60.5ms
# Speed: 7.1ms preprocess, 60.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 1 LCV, 14 M2Ws, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 14 M2Ws, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 16 M2Ws, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 58 Carss, 1 LCV, 14 M2Ws, 8 Rickshaws, 1 Truck, 58.9ms
# Speed: 11.7ms preprocess, 58.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 59 Carss, 1 LCV, 17 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.3ms
# Speed: 12.1ms preprocess, 60.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 57 Carss, 1 LCV, 18 M2Ws, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 55 Carss, 1 LCV, 18 M2Ws, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.9ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 18 M2Ws, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 61 Carss, 1 LCV, 15 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 1 LCV, 16 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.1ms
# Speed: 7.6ms preprocess, 59.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 13 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.5ms preprocess, 58.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 1 LCV, 15 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.3ms
# Speed: 7.8ms preprocess, 60.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 60 Carss, 1 LCV, 13 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.5ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 13 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.9ms preprocess, 58.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 53 Carss, 1 LCV, 15 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.8ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 48 Carss, 1 LCV, 12 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.3ms
# Speed: 7.4ms preprocess, 60.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 48 Carss, 1 LCV, 11 M2Ws, 1 MAV, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.8ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 49 Carss, 1 LCV, 11 M2Ws, 1 MAV, 3 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.2ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 48 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 59.6ms
# Speed: 14.6ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 47 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 47 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 9.1ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 45 Carss, 1 LCV, 8 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 15.8ms preprocess, 58.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 47 Carss, 1 LCV, 7 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.8ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.3ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 42 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 47 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 9.0ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 45 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.8ms preprocess, 58.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 46 Carss, 1 LCV, 6 M2Ws, 2 MAVs, 8 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.8ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 48 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.2ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 2 LCVs, 8 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.2ms preprocess, 58.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 51 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 8 Rickshaws, 1 Truck, 58.5ms
# Speed: 12.1ms preprocess, 58.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 59.0ms
# Speed: 12.1ms preprocess, 59.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 64.9ms
# Speed: 13.8ms preprocess, 64.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 52 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 68.1ms
# Speed: 13.1ms preprocess, 68.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 54 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 65.8ms
# Speed: 9.6ms preprocess, 65.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 11 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 10.0ms preprocess, 58.6ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 56 Carss, 1 LCV, 11 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.3ms
# Speed: 19.6ms preprocess, 59.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 53 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.5ms
# Speed: 8.2ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 54 Carss, 1 LCV, 11 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 15.0ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 56 Carss, 1 LCV, 10 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 58 Carss, 1 LCV, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 63.6ms
# Speed: 14.4ms preprocess, 63.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 8 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 12.5ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 56 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 12.6ms preprocess, 58.4ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 56 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.5ms
# Speed: 15.7ms preprocess, 58.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 54 Carss, 1 LCV, 7 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 11.1ms preprocess, 58.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 52 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 64.5ms
# Speed: 14.3ms preprocess, 64.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 54 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.1ms
# Speed: 14.6ms preprocess, 60.1ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 52 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.7ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 52 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.6ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 3 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.0ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 2 LCVs, 11 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.4ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 2 LCVs, 13 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.5ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.6ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 53 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.4ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 54 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 60.1ms
# Speed: 7.5ms preprocess, 60.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 55 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 49 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.5ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 54 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 59.5ms
# Speed: 7.8ms preprocess, 59.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 50 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.8ms
# Speed: 8.9ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 52 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.4ms preprocess, 58.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 52 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.5ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 52 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 59.1ms
# Speed: 7.5ms preprocess, 59.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 54 Carss, 1 LCV, 9 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 52 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.2ms preprocess, 58.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 53 Carss, 1 LCV, 13 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.2ms preprocess, 58.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 50 Carss, 1 LCV, 13 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.1ms
# Speed: 7.5ms preprocess, 59.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 50 Carss, 1 LCV, 12 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 24.2ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 13 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 13 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.9ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 64.7ms
# Speed: 7.6ms preprocess, 64.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 8 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 50 Carss, 1 LCV, 10 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.5ms
# Speed: 8.5ms preprocess, 58.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 49 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.7ms
# Speed: 8.1ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 51 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.8ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 53 Carss, 1 LCV, 8 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 60.4ms
# Speed: 7.5ms preprocess, 60.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 53 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.8ms preprocess, 58.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 55 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 55 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 54 Carss, 1 LCV, 13 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.5ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 55 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.5ms
# Speed: 7.8ms preprocess, 58.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.9ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 63 Carss, 1 LCV, 13 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.9ms
# Speed: 7.4ms preprocess, 58.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 63.4ms
# Speed: 7.3ms preprocess, 63.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.5ms
# Speed: 9.2ms preprocess, 58.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 59 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.5ms
# Speed: 7.6ms preprocess, 58.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 62 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.5ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 66 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.3ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 59 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 61.5ms
# Speed: 8.8ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 60 Carss, 1 LCV, 16 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 61 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 3 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.9ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 61 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.5ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 65 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 63 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.5ms
# Speed: 8.0ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 63 Carss, 1 LCV, 13 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 59.2ms
# Speed: 7.9ms preprocess, 59.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 63 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 62.4ms
# Speed: 7.8ms preprocess, 62.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 62 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 66.5ms
# Speed: 12.1ms preprocess, 66.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 61 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.6ms
# Speed: 17.6ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 62 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 64.9ms
# Speed: 7.5ms preprocess, 64.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 62 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 65.2ms
# Speed: 14.8ms preprocess, 65.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 63.1ms
# Speed: 9.3ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 61 Carss, 1 LCV, 15 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.0ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 57 Carss, 2 LCVs, 15 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 60.1ms
# Speed: 11.9ms preprocess, 60.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 57 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 60.9ms
# Speed: 10.2ms preprocess, 60.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 59 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.4ms
# Speed: 12.4ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 63.3ms
# Speed: 15.7ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 59 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 4 Rickshaws, 2 Trucks, 58.5ms
# Speed: 13.9ms preprocess, 58.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 65.4ms
# Speed: 10.1ms preprocess, 65.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 11 M2Ws, 2 MAVs, 6 Rickshaws, 2 Trucks, 58.4ms
# Speed: 16.7ms preprocess, 58.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 61 Carss, 1 LCV, 13 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.9ms
# Speed: 17.4ms preprocess, 58.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 61 Carss, 1 LCV, 16 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.2ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 59 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.9ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 15 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 60.3ms
# Speed: 7.8ms preprocess, 60.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 61 Carss, 1 LCV, 21 M2Ws, 2 MAVs, 8 Rickshaws, 2 Trucks, 58.4ms
# Speed: 6.4ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 57 Carss, 1 LCV, 15 M2Ws, 1 MAV, 7 Rickshaws, 2 Trucks, 58.5ms
# Speed: 7.7ms preprocess, 58.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 55 Carss, 1 LCV, 15 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 15 M2Ws, 1 MAV, 6 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 16 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 16 M2Ws, 1 MAV, 4 Rickshaws, 2 Trucks, 60.1ms
# Speed: 7.5ms preprocess, 60.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 17 M2Ws, 1 MAV, 5 Rickshaws, 2 Trucks, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 54 Carss, 1 LCV, 17 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 18 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 59.4ms
# Speed: 8.3ms preprocess, 59.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 57 Carss, 1 LCV, 16 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.6ms preprocess, 58.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 57 Carss, 1 LCV, 16 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 11.5ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 19 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 59.1ms
# Speed: 8.9ms preprocess, 59.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 18 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.6ms
# Speed: 12.5ms preprocess, 58.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 58 Carss, 1 LCV, 19 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.4ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 58 Carss, 1 LCV, 18 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 59.2ms
# Speed: 7.7ms preprocess, 59.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 56 Carss, 1 LCV, 18 M2Ws, 1 MAV, 5 Rickshaws, 1 Truck, 58.8ms
# Speed: 8.2ms preprocess, 58.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 1 LCV, 17 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 8.3ms preprocess, 58.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 56 Carss, 2 LCVs, 17 M2Ws, 2 MAVs, 4 Rickshaws, 1 Truck, 58.5ms
# Speed: 8.0ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 56 Carss, 2 LCVs, 18 M2Ws, 2 MAVs, 5 Rickshaws, 2 Trucks, 58.3ms
# Speed: 7.8ms preprocess, 58.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 55 Carss, 1 LCV, 18 M2Ws, 2 MAVs, 5 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 56 Carss, 1 LCV, 19 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# ...
# Speed: 7.8ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 72 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 12 Rickshaws, 2 Trucks, 58.9ms
# Speed: 7.7ms preprocess, 58.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 70 Carss, 1 LCV, 8 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 10.6ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 72 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.2ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 70 Carss, 1 LCV, 13 M2Ws, 1 MAV, 10 Rickshaws, 2 Trucks, 58.8ms
# Speed: 7.6ms preprocess, 58.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 71 Carss, 1 LCV, 13 M2Ws, 1 MAV, 13 Rickshaws, 2 Trucks, 58.8ms
# Speed: 7.9ms preprocess, 58.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 69 Carss, 1 LCV, 12 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.4ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 72 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 12 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 72 Carss, 2 LCVs, 9 M2Ws, 2 MAVs, 13 Rickshaws, 2 Trucks, 58.4ms
# Speed: 8.2ms preprocess, 58.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 72 Carss, 1 LCV, 12 M2Ws, 1 MAV, 11 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 69 Carss, 1 LCV, 12 M2Ws, 1 MAV, 13 Rickshaws, 1 Truck, 58.7ms
# Speed: 11.1ms preprocess, 58.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 73 Carss, 1 LCV, 12 M2Ws, 1 MAV, 13 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.3ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 73 Carss, 1 LCV, 13 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 59.1ms
# Speed: 7.9ms preprocess, 59.1ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 74 Carss, 1 LCV, 13 M2Ws, 1 MAV, 12 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 74 Carss, 1 LCV, 12 M2Ws, 1 MAV, 13 Rickshaws, 1 Truck, 59.4ms
# Speed: 7.6ms preprocess, 59.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 76 Carss, 1 LCV, 11 M2Ws, 1 MAV, 13 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.6ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 73 Carss, 1 LCV, 17 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 60.2ms
# Speed: 7.6ms preprocess, 60.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 70 Carss, 2 LCVs, 10 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 58.8ms
# Speed: 8.5ms preprocess, 58.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 74 Carss, 1 LCV, 13 M2Ws, 1 MAV, 9 Rickshaws, 2 Trucks, 58.8ms
# Speed: 9.3ms preprocess, 58.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 71 Carss, 1 LCV, 10 M2Ws, 1 MAV, 13 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 70 Carss, 1 LCV, 9 M2Ws, 1 MAV, 13 Rickshaws, 1 Truck, 61.6ms
# Speed: 20.2ms preprocess, 61.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 73 Carss, 1 LCV, 16 M2Ws, 1 MAV, 15 Rickshaws, 1 Truck, 63.0ms
# Speed: 7.8ms preprocess, 63.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 68 Carss, 1 LCV, 17 M2Ws, 1 MAV, 15 Rickshaws, 2 Trucks, 59.8ms
# Speed: 13.5ms preprocess, 59.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 12 M2Ws, 1 MAV, 14 Rickshaws, 1 Truck, 69.6ms
# Speed: 7.8ms preprocess, 69.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 69 Carss, 1 LCV, 12 M2Ws, 1 MAV, 10 Rickshaws, 2 Trucks, 58.5ms
# Speed: 14.9ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 9 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 59.6ms
# Speed: 19.0ms preprocess, 59.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 69 Carss, 1 LCV, 9 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 14.8ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 3 Buss, 71 Carss, 1 LCV, 13 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 63.0ms
# Speed: 7.6ms preprocess, 63.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 72 Carss, 1 LCV, 11 M2Ws, 1 MAV, 11 Rickshaws, 1 Truck, 65.3ms
# Speed: 11.2ms preprocess, 65.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 72 Carss, 1 LCV, 11 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 59.9ms
# Speed: 12.8ms preprocess, 59.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 72 Carss, 1 LCV, 11 M2Ws, 2 MAVs, 9 Rickshaws, 1 Truck, 63.6ms
# Speed: 17.0ms preprocess, 63.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 73 Carss, 1 LCV, 11 M2Ws, 1 MAV, 9 Rickshaws, 1 Truck, 58.8ms
# Speed: 9.8ms preprocess, 58.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 71 Carss, 1 LCV, 11 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 60.4ms
# Speed: 12.6ms preprocess, 60.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 73 Carss, 1 LCV, 11 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 61.8ms
# Speed: 9.1ms preprocess, 61.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 71 Carss, 1 LCV, 13 M2Ws, 1 MAV, 11 Rickshaws, 2 Trucks, 58.5ms
# Speed: 13.9ms preprocess, 58.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 70 Carss, 1 LCV, 10 M2Ws, 1 MAV, 9 Rickshaws, 2 Trucks, 58.4ms
# Speed: 15.1ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 70 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 7 Rickshaws, 2 Trucks, 58.7ms
# Speed: 14.7ms preprocess, 58.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 70 Carss, 1 LCV, 14 M2Ws, 2 MAVs, 8 Rickshaws, 2 Trucks, 59.6ms
# Speed: 11.5ms preprocess, 59.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 61 Carss, 1 LCV, 12 M2Ws, 2 MAVs, 13 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.8ms preprocess, 58.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 65 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 8.2ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 69 Carss, 1 LCV, 10 M2Ws, 2 MAVs, 10 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 63 Carss, 13 M2Ws, 2 MAVs, 10 Rickshaws, 2 Trucks, 58.4ms
# Speed: 14.0ms preprocess, 58.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 13 M2Ws, 2 MAVs, 11 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 12 M2Ws, 2 MAVs, 13 Rickshaws, 2 Trucks, 58.4ms
# Speed: 7.7ms preprocess, 58.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 10 M2Ws, 2 MAVs, 12 Rickshaws, 2 Trucks, 58.4ms
# Speed: 8.0ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 12 M2Ws, 2 MAVs, 13 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 10 M2Ws, 2 MAVs, 11 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.9ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 69 Carss, 12 M2Ws, 2 MAVs, 13 Rickshaws, 2 Trucks, 58.4ms
# Speed: 8.3ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 67 Carss, 12 M2Ws, 2 MAVs, 11 Rickshaws, 2 Trucks, 58.4ms
# Speed: 9.5ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 68 Carss, 10 M2Ws, 2 MAVs, 12 Rickshaws, 2 Trucks, 60.4ms
# Speed: 7.6ms preprocess, 60.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 15 M2Ws, 2 MAVs, 10 Rickshaws, 2 Trucks, 58.5ms
# Speed: 5.6ms preprocess, 58.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 13 M2Ws, 2 MAVs, 10 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.8ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 10 M2Ws, 2 MAVs, 9 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 13 M2Ws, 2 MAVs, 10 Rickshaws, 2 Trucks, 58.7ms
# Speed: 7.7ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 13 M2Ws, 2 MAVs, 9 Rickshaws, 1 Truck, 58.9ms
# Speed: 7.8ms preprocess, 58.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 62 Carss, 11 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.1ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 1 LCV, 9 M2Ws, 2 MAVs, 6 Rickshaws, 1 Truck, 58.9ms
# Speed: 8.0ms preprocess, 58.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 62 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.7ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 1 LCV, 10 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.2ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 60 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 9 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.9ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 1 LCV, 7 M2Ws, 2 MAVs, 7 Rickshaws, 1 Truck, 58.9ms
# Speed: 11.1ms preprocess, 58.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 11 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.4ms preprocess, 58.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 15 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.8ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 62 Carss, 12 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 59.3ms
# Speed: 8.2ms preprocess, 59.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 62 Carss, 11 M2Ws, 7 Rickshaws, 1 Truck, 58.8ms
# Speed: 7.8ms preprocess, 58.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 63 Carss, 11 M2Ws, 8 Rickshaws, 1 Truck, 58.6ms
# Speed: 6.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 62 Carss, 10 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.7ms
# Speed: 8.3ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 9 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.5ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 65 Carss, 9 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 58.5ms
# Speed: 10.4ms preprocess, 58.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 60 Carss, 8 M2Ws, 1 MAV, 9 Rickshaws, 1 Truck, 59.5ms
# Speed: 7.8ms preprocess, 59.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 63 Carss, 8 M2Ws, 1 MAV, 10 Rickshaws, 1 Truck, 58.6ms
# Speed: 9.6ms preprocess, 58.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 64 Carss, 8 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 7.6ms preprocess, 58.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 67 Carss, 12 M2Ws, 1 MAV, 9 Rickshaws, 1 Truck, 58.6ms
# Speed: 8.7ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 69 Carss, 13 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.5ms
# Speed: 7.6ms preprocess, 58.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 68 Carss, 10 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 10.3ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 67 Carss, 13 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.7ms
# Speed: 19.0ms preprocess, 58.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 13 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.5ms
# Speed: 12.9ms preprocess, 58.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 66 Carss, 1 LCV, 13 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 60.5ms
# Speed: 10.6ms preprocess, 60.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 2 Buss, 63 Carss, 1 LCV, 8 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.7ms
# Speed: 13.9ms preprocess, 58.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 1 LCV, 11 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.6ms preprocess, 58.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 64 Carss, 1 LCV, 12 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.6ms
# Speed: 7.7ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 1 LCV, 10 M2Ws, 1 MAV, 6 Rickshaws, 1 Truck, 65.2ms
# Speed: 12.7ms preprocess, 65.2ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 67 Carss, 12 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 14.7ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 11 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.6ms
# Speed: 11.2ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 67 Carss, 11 M2Ws, 1 MAV, 7 Rickshaws, 1 Truck, 58.5ms
# Speed: 11.2ms preprocess, 58.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 9 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.4ms
# Speed: 14.3ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 66 Carss, 12 M2Ws, 1 MAV, 8 Rickshaws, 1 Truck, 58.8ms
# Speed: 9.3ms preprocess, 58.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 67 Carss, 10 M2Ws, 2 MAVs, 9 Rickshaws, 1 Truck, 58.4ms
# Speed: 8.7ms preprocess, 58.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 65 Carss, 9 M2Ws, 7 Rickshaws, 1 Truck, 58.3ms
# Speed: 10.1ms preprocess, 58.3ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 1088)
#
# 0: 640x1088 1 Bus, 68 Carss, 8 M2Ws, 7 Rickshaws, 1 Truck, 58.4ms
# Speed: 7.4ms preprocess, 58.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1088)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tkinter import *

# %%
def calculate_acceleration(df):
    df['acceleration'] = df.groupby('tracker_id')['speed'].diff() / 10  # Assuming 10 frame = 1 second
    return df

# %%
df.head()
# Out:
#    frame_number  tracker_id  class  speed  acceleration
# 0             0           1      1    0.0           NaN
# 1             0           2      1    0.0           NaN
# 2             0           3      6    0.0           NaN
# 3             0           4      1    0.0           NaN
# 4             0           5      1    0.0           NaN

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import pandas as pd
df = calculate_acceleration(df)
#df = calculate_tangential_acceleration(df)

def plot_graphs(change):
    tracker_id = change['new']
    specific_df = df[df['tracker_id'] == tracker_id]
    print('\n')
    print('Class : ',specific_df['class'][0])
    print('\n')

    plt.figure()
    plt.plot(specific_df['frame_number'], specific_df['speed'],color='r')
    plt.title('Speed vs Time')
    plt.xlabel('Frame Number')
    plt.ylabel('Speed (km/hr)')
    plt.grid()

    plt.figure()
    plt.plot(specific_df['frame_number'], specific_df['acceleration'],color='g')
    plt.title('Acceleration vs Time')
    plt.xlabel('Frame Number')
    plt.ylabel('Acceleration (km/hr^2)')
    plt.grid()

    # plt.figure()
    # plt.plot(specific_df['frame_number'], specific_df['tangential_acceleration'],color='orange')
    # plt.title('Tangential Acceleration vs Time')
    # plt.xlabel('Frame Number')
    # plt.ylabel('Tangential Acceleration (km/hr^2)')

    # plt.show()

# Create a dropdown for tracker IDs
tracker_ids = df['tracker_id'].unique().tolist()
tracker_id_dropdown = widgets.Dropdown(
    options=tracker_ids,
    value=tracker_ids[0],
    description='Tracker ID:',
    disabled=False,
)

tracker_id_dropdown.observe(plot_graphs, names='value')

# Save DataFrame to CSV
df.to_csv('/content/drive/MyDrive/Speed Estimation/data.csv', index=False, header=True)

# Display the dropdown
display(tracker_id_dropdown)
